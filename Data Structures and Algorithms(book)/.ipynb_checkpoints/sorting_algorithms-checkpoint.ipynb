# %% [markdown]
# ## 1(i) Bubble Sort
# the bubble sort makes multiple passes through a list, it compares the item to its adjacent item and exchange them if they are out of order. and keep doing this for number of passes
# * if there are (n) items in the list, then there are (n - 1) pairs of items that need to be compared on the first pass

# %%
def bubble_sort(a_list):
    for pass_num in range(len(a_list) - 1, 0, -1):
        for i in range(pass_num):
            if a_list[i] > a_list[i + 1]:
                temp = a_list[i]
                a_list[i] = a_list[i+1]
                a_list[i+1] = temp

# %%
a_list = [54, 26, 93, 17, 77, 31, 44, 55, 20]
bubble_sort(a_list)
print(a_list)
# Out:
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %% [markdown]
# ### Analysis of Bubble Sort Algorithm:
# we should note that regardless of how the items are arranged in the initial list, (n - 1) passes will be needed to sort the list of size (n).
# the first pass need (n - 1) comparisons and the number of comparisons keeps decreasing by (1) after each pass.
# so, the total number of comparisons
# is the sum of the first (n - 1) integers
# which is -> (0.5*n^2 - 0.5*n)
# which gives approximately O(n^2)

# %% [markdown]
# ## 1(ii) Short Bubble Sort:
# a bubble sort that can be stopped early if it finds the the list has becomed sorted.

# %%
def short_bubble_sort(a_list):
    exchange = True
    pass_num = len(a_list) - 1
    while pass_num > 0 and exchange:
        exchange = False
        for i in range(pass_num):
            if a_list[i] > a_list[i+1]:
                exchange = True
                temp = a_list[i]
                a_list[i] = a_list[i+1]
                a_list[i+1] = temp
        pass_num -= 1

# %%
a_list=[20, 30, 40, 90, 50, 60, 70, 80, 100, 110]
short_bubble_sort(a_list)
print(a_list)
# Out:
# [20, 30, 40, 50, 60, 70, 80, 90, 100, 110]

# %% [markdown]
# ## 2- Selection Sort
# Improves on the bubble sort by making only one exchange per one pass, by looking throught the largest value and places it in the proper location

# %%
def selection_sort(a_list):
    for fill_slot in range(len(a_list) - 1, 0, -1):
        pos_of_max = 0
        for location in range(1, fill_slot + 1):  # for finding the position of the max value
            if a_list[location] > a_list[pos_of_max]:  
                pos_of_max = location
        temp = a_list[fill_slot]
        a_list[fill_slot] = a_list[pos_of_max]
        a_list[pos_of_max] = temp

# %%
a_list = [54, 26, 93, 17, 77, 31, 44, 55, 20]
selection_sort(a_list)
print(a_list)
# Out:
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %% [markdown]
# ### Analysis of Selection Sort Algorithm:
# the selection sort make the same number of comparisons as the bubble sort, but the reduction of the number of exchanges make the selection sort executes faster.

# %% [markdown]
# ## 3- The Insertion Sort
# the insertion sort is still O(n^2), works in a slightly different way.
# it always maintains a sorted sublist in the lower positions of the list.
# each new item is then inserted back into the previous sublist such that the sorted sublist is one item larger.
# * we begin by assuming that the a list with one item(position 0), is already sorted.

# %%
def insertion_sort(a_list):
    # we are assuming that the first element in the list is ordered
    # So we will begin with the second element in our list.
    for index in range(1, len(a_list)):
        current_value = a_list[index]
        position = index
        while position > 0 and a_list[position - 1] > current_value:
            a_list[position] = a_list[position - 1]
            position -= 1
        
        a_list[position] = current_value

# %%
a_list = [54, 26, 93, 17, 77, 31, 44, 55, 20]
insertion_sort(a_list)
print(a_list)
# Out:
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %% [markdown]
# ## 4- Shell Sort
# sometimes called "the diminishing increment sort", improves on the insertion sort by breaking the original list into a number of smaller sublists, each of which is sorted using an insertion sort.
# the shell sort uses an increment (i), sometimes called the "gap"
# "To Create a Sublist by Choosing All Items That are (i) Items Apart"
#
# ![image.png](attachment:aad05cbb-4372-4010-81df-b5c18d91a6bb.png)

# %%
def shell_sort(a_list):
    sub_list_count = len(a_list) // 2
    while sub_list_count > 0:
        for start_position in range(sub_list_count):
            gap_insertion_sort(a_list, start_position, sub_list_count)
        print("After increments of size", sub_list_count, "The list is", a_list)
        sub_list_count = sub_list_count // 2
        
def gap_insertion_sort(a_list, start, gap):
    for i in range(start + gap, len(a_list), gap):
        current_value = a_list[i]
        position = i
        while position >= gap and a_list[position - gap] > current_value:
            a_list[position] = a_list[position - gap]
            position = position - gap
        a_list[position] = current_value

# %%
a_list = [54, 26, 93, 17, 77, 31, 44, 55, 20]
shell_sort(a_list)
print(a_list)
# Out:
# After increments of size 4 The list is [20, 26, 44, 17, 54, 31, 93, 55, 77]
# After increments of size 2 The list is [20, 17, 44, 26, 54, 31, 77, 55, 93]
# After increments of size 1 The list is [17, 20, 26, 31, 44, 54, 55, 77, 93]
# [17, 20, 26, 31, 44, 54, 55, 77, 93]
